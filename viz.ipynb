# %%
import matplotlib.pyplot as plt

# %%
dev_reward_kb13 = [8.2407, 8.8117, 11.7243, 12.7052, 13.5858, 14.2488, 14.7656, 15.2612, 15.6687, 15.9384]
plt.plot(range(10), dev_reward_kb13, label= 'KB-13');
dev_reward_nlsynth = [13.0959, 14.8902, 15.5548, 15.9156, 16.1545, 16.3454, 16.4871, 16.6192, 16.7278, 16.8141]
plt.plot(range(10), dev_reward_nlsynth, label='NL-RX Synth');
dev_reward_nlturk = [13.8043, 15.5908, 16.3350, 17.0112, 17.3625, 17.7605, 18.1779, 18.4721, 18.7389, 18.9391]
plt.plot(range(10), dev_reward_nlturk, label='NL-RX Turk');
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Validation Reward')
plt.title('Validation Reward for reBERTh');
plt.savefig('pic.png')

# %%
# !pwd
# Out:
# /Users/kunalagarwal/Desktop/GitHub/CS/info256/softregex/regex_equal_model
