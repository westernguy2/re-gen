# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install sacrebleu
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-ndaviebi
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-ndaviebi
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 5.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (3.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (1.19.5)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 404 kB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 35.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (21.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 68.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.14.0.dev0) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.14.0.dev0) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.14.0.dev0) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.14.0.dev0) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.0.dev0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.0.dev0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.0.dev0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.14.0.dev0) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.14.0.dev0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.14.0.dev0) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.14.0.dev0) (1.15.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.14.0.dev0-py3-none-any.whl size=3320842 sha256=7ddf52e988d5a15e3323120d7e904f6c1812737abac968113abb066c495974f9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ahjipbg4/wheels/35/2e/a7/d819e3310040329f0f47e57c9e3e7a7338aa5e74c49acfe522
# Successfully built transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.14.0.dev0
# Collecting datasets
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 5.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.2.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 60.7 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.8.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 49.1 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 59.1 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 57.6 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.8)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 57.5 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 59.0 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.6.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, datasets
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 datasets-1.16.1 frozenlist-1.2.0 fsspec-2021.11.1 multidict-5.2.0 xxhash-2.0.2 yarl-1.7.2
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.2 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.2 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %% [markdown]
# ## KB13

# %%
from transformers import LineByLineTextDataset
from transformers import T5Tokenizer, T5ForConditionalGeneration
from datasets import load_dataset, load_metric, dataset_dict, DatasetDict
import torch
import numpy as np

tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")
dataset = load_dataset("csv", data_files="/content/drive/MyDrive/ANLP21/data/labeled_regex_data/labeled_kb13.csv", split="train")
_dataset_dict = dataset.train_test_split(test_size=0.25)
train_val = _dataset_dict["train"].train_test_split(test_size=10/75)
train = train_val["train"]
val = train_val['test']
test = _dataset_dict["test"]
d = dataset_dict.DatasetDict({'train':train, 'val': val, 'test':test})
metric = load_metric("sacrebleu")
# Out:
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Using custom data configuration default-d6f6847834d41d0b
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-d6f6847834d41d0b/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-d6f6847834d41d0b/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.
# Downloading:   0%|          | 0.00/2.37k [00:00<?, ?B/s]

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer, model=model
)

# %%
d
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 535
#     })
#     val: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 83
#     })
#     test: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 206
#     })
# })

# %%
max_input_length = 512
max_target_length = 128
def preprocess_function(dataset):
    inputs = dataset["label"]
    targets = dataset["regex"]
    model_inputs = tokenizer(inputs, max_length=max_input_length, padding=True, truncation=True)
    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, padding=True, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

datasets = d.map(preprocess_function, batched=True)

for dataset in datasets:
  datasets[dataset] = datasets[dataset].remove_columns(["label", "regex"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
t5_path = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex/kb13"
t5_cuda_path = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13"
# !mkdir -p $t5_path
# !mkdir -p $t5_cuda_path

# %%
d.save_to_disk(t5_cuda_path)
# Out:
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels
    
def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
# from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

# batch_size = 64

# training_args = Seq2SeqTrainingArguments(
#     t5_path,
#     evaluation_strategy = "epoch",
#     learning_rate=3e-4,
#     per_device_train_batch_size=batch_size,
#     per_device_eval_batch_size=batch_size,
#     save_steps=100,
#     save_total_limit=10,
#     num_train_epochs=35,
#     predict_with_generate=True    
# )

# trainer = Seq2SeqTrainer(
#     model,
#     training_args,
#     train_dataset=datasets["train"],
#     eval_dataset=datasets["val"],
#     data_collator=data_collator,
#     tokenizer=tokenizer,
#     compute_metrics=compute_metrics
# )

# %%
# trainer.train()

# %%
# trainer.save_model(t5_path)

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

batch_size = 64

cuda_training_args = Seq2SeqTrainingArguments(
    t5_cuda_path,
    evaluation_strategy = "epoch",
    learning_rate=3e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    save_steps=100,
    save_total_limit=10,
    num_train_epochs=35,
    predict_with_generate=True    
)

cuda_trainer = Seq2SeqTrainer(
    model,
    cuda_training_args,
    train_dataset=datasets["train"],
    eval_dataset=datasets["val"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
cuda_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 535
#   Num Epochs = 35
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 315
#     <div>
#
#       <progress value='315' max='315' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [315/315 08:24, Epoch 35/35]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.216153</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.776313</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.517253</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.366693</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.265154</td>
#       <td>22.551200</td>
#       <td>14.445800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>0.242240</td>
#       <td>25.073000</td>
#       <td>16.253000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>0.218694</td>
#       <td>24.919900</td>
#       <td>14.253000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>0.204570</td>
#       <td>27.056000</td>
#       <td>14.349400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>0.196023</td>
#       <td>29.337100</td>
#       <td>14.457800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>0.188451</td>
#       <td>29.021100</td>
#       <td>14.072300</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>0.178841</td>
#       <td>32.802600</td>
#       <td>13.686700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>0.176511</td>
#       <td>36.695100</td>
#       <td>14.578300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>0.171792</td>
#       <td>36.192200</td>
#       <td>13.530100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>0.168782</td>
#       <td>34.642900</td>
#       <td>13.481900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>0.164548</td>
#       <td>34.896500</td>
#       <td>13.542200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>No log</td>
#       <td>0.167945</td>
#       <td>37.992800</td>
#       <td>13.855400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>No log</td>
#       <td>0.161814</td>
#       <td>35.352300</td>
#       <td>13.518100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>No log</td>
#       <td>0.155293</td>
#       <td>37.001000</td>
#       <td>13.879500</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>No log</td>
#       <td>0.155317</td>
#       <td>36.190000</td>
#       <td>13.963900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>No log</td>
#       <td>0.155733</td>
#       <td>36.498400</td>
#       <td>13.662700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>No log</td>
#       <td>0.154271</td>
#       <td>37.721700</td>
#       <td>13.722900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>No log</td>
#       <td>0.150181</td>
#       <td>39.073300</td>
#       <td>13.783100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>No log</td>
#       <td>0.149822</td>
#       <td>37.832700</td>
#       <td>13.759000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>No log</td>
#       <td>0.149400</td>
#       <td>40.026200</td>
#       <td>13.734900</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>No log</td>
#       <td>0.149834</td>
#       <td>38.529000</td>
#       <td>13.506000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>No log</td>
#       <td>0.149111</td>
#       <td>39.627700</td>
#       <td>13.734900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>No log</td>
#       <td>0.149111</td>
#       <td>39.717500</td>
#       <td>13.710800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>No log</td>
#       <td>0.149397</td>
#       <td>39.858600</td>
#       <td>13.626500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>No log</td>
#       <td>0.148123</td>
#       <td>41.295400</td>
#       <td>13.807200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>No log</td>
#       <td>0.147381</td>
#       <td>41.994600</td>
#       <td>13.915700</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>No log</td>
#       <td>0.145874</td>
#       <td>40.974600</td>
#       <td>13.807200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>No log</td>
#       <td>0.145782</td>
#       <td>40.539400</td>
#       <td>13.783100</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>No log</td>
#       <td>0.145338</td>
#       <td>41.254100</td>
#       <td>13.783100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>No log</td>
#       <td>0.145000</td>
#       <td>41.254100</td>
#       <td>13.783100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>No log</td>
#       <td>0.145009</td>
#       <td>40.912500</td>
#       <td>13.747000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-100/spiece.model
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-200/spiece.model
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/checkpoint-300/spiece.model
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
# ***** Running Evaluation *****
#   Num examples = 83
#   Batch size = 64
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=315, training_loss=0.2813703991117932, metrics={'train_runtime': 506.4054, 'train_samples_per_second': 36.976, 'train_steps_per_second': 0.622, 'total_flos': 569221976064000.0, 'train_loss': 0.2813703991117932, 'epoch': 35.0})

# %%
cuda_trainer.save_model(t5_cuda_path)
# Out:
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13/spiece.model

# %% [markdown]
# ## NL-RX Synth

# %%
from transformers import LineByLineTextDataset
from transformers import T5Tokenizer, T5ForConditionalGeneration
from datasets import load_dataset, load_metric, dataset_dict
import torch
import numpy as np

tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")
dataset = load_dataset("csv", data_files="/content/drive/MyDrive/ANLP21/data/labeled_regex_data/labeled_nlrx_synth.csv", split="train")
_dataset_dict = dataset.train_test_split(test_size=0.25)
train_val = _dataset_dict["train"].train_test_split(test_size=10/75)
train = train_val["train"]
val = train_val['test']
test = _dataset_dict["test"]
d = dataset_dict.DatasetDict({'train':train, 'val': val, 'test':test})
metric = load_metric("sacrebleu")
# Out:
# loading file https://huggingface.co/t5-small/resolve/main/spiece.model from cache at /root/.cache/huggingface/transformers/65fc04e21f45f61430aea0c4fedffac16a4d20d78b8e6601d8d996ebefefecd2.3b69006860e7b5d0a63ffdddc01ddcd6b7c318a6f4fd793596552c741734c62d
# loading file https://huggingface.co/t5-small/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/tokenizer_config.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/06779097c78e12f47ef67ecb728810c2ae757ee0a9efe9390c6419783d99382d.8627f1bd5d270a9fd2e5a51c8bec3223896587cc3cfe13edeabb0992ab43c529
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.406701565c0afd9899544c1cb8b93185a76f00b31e5ce7f6e18bbaef02241985
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.14.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.406701565c0afd9899544c1cb8b93185a76f00b31e5ce7f6e18bbaef02241985
# Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.14.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file https://huggingface.co/t5-small/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# Using custom data configuration default-61a25f6569b0a17f
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-61a25f6569b0a17f/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-61a25f6569b0a17f/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer, model=model
)

# %%
d
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 6500
#     })
#     val: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 1000
#     })
#     test: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 2500
#     })
# })

# %%
max_input_length = 512
max_target_length = 128
def preprocess_function(dataset):
    inputs = dataset["label"]
    targets = dataset["regex"]
    model_inputs = tokenizer(inputs, max_length=max_input_length, padding=True, truncation=True)
    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, padding=True, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

datasets = d.map(preprocess_function, batched=True)

for dataset in datasets:
  datasets[dataset] = datasets[dataset].remove_columns(["label", "regex"])
# Out:
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
t5_path = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex/nlrx_synth"
t5_cuda_path = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth"
# !mkdir -p $t5_path
# !mkdir -p $t5_cuda_path

# %%
d.save_to_disk(t5_cuda_path)
# Out:
# Flattening the indices:   0%|          | 0/7 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels
    
def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
# from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

# batch_size = 64

# training_args = Seq2SeqTrainingArguments(
#     t5_path,
#     evaluation_strategy = "epoch",
#     learning_rate=3e-4,
#     per_device_train_batch_size=batch_size,
#     per_device_eval_batch_size=batch_size,
#     save_steps=100,
#     save_total_limit=10,
#     num_train_epochs=35,
#     predict_with_generate=True    
# )

# trainer = Seq2SeqTrainer(
#     model,
#     training_args,
#     train_dataset=datasets["train"],
#     eval_dataset=datasets["val"],
#     data_collator=data_collator,
#     tokenizer=tokenizer,
#     compute_metrics=compute_metrics
# )

# %%
# trainer.save_model(t5_path)

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

batch_size = 64

cuda_training_args = Seq2SeqTrainingArguments(
    t5_cuda_path,
    evaluation_strategy = "epoch",
    learning_rate=3e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    save_steps=100,
    save_total_limit=10,
    num_train_epochs=35,
    predict_with_generate=True    
)

cuda_trainer = Seq2SeqTrainer(
    model,
    cuda_training_args,
    train_dataset=datasets["train"],
    eval_dataset=datasets["val"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
cuda_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 6500
#   Num Epochs = 35
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3570
#     <div>
#
#       <progress value='3570' max='3570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3570/3570 1:14:31, Epoch 35/35]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.066866</td>
#       <td>70.175300</td>
#       <td>17.907000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.030015</td>
#       <td>72.691800</td>
#       <td>18.136000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.018093</td>
#       <td>73.680800</td>
#       <td>18.157000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.013549</td>
#       <td>74.263500</td>
#       <td>18.154000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.192800</td>
#       <td>0.013140</td>
#       <td>74.201300</td>
#       <td>18.158000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.192800</td>
#       <td>0.010173</td>
#       <td>74.516000</td>
#       <td>18.158000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.192800</td>
#       <td>0.008344</td>
#       <td>74.613500</td>
#       <td>18.162000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.192800</td>
#       <td>0.007474</td>
#       <td>74.632200</td>
#       <td>18.162000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.192800</td>
#       <td>0.007226</td>
#       <td>74.669700</td>
#       <td>18.160000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.016800</td>
#       <td>0.007183</td>
#       <td>74.752300</td>
#       <td>18.162000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.016800</td>
#       <td>0.006947</td>
#       <td>74.660200</td>
#       <td>18.160000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.016800</td>
#       <td>0.006386</td>
#       <td>74.725600</td>
#       <td>18.168000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.016800</td>
#       <td>0.006192</td>
#       <td>74.975100</td>
#       <td>18.164000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.016800</td>
#       <td>0.006195</td>
#       <td>74.488700</td>
#       <td>18.162000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.010700</td>
#       <td>0.006640</td>
#       <td>74.886400</td>
#       <td>18.167000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.010700</td>
#       <td>0.006079</td>
#       <td>74.753200</td>
#       <td>18.161000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.010700</td>
#       <td>0.005813</td>
#       <td>74.858900</td>
#       <td>18.160000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.010700</td>
#       <td>0.005825</td>
#       <td>74.907200</td>
#       <td>18.161000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.010700</td>
#       <td>0.005781</td>
#       <td>74.681700</td>
#       <td>18.156000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.008700</td>
#       <td>0.006319</td>
#       <td>74.660100</td>
#       <td>18.157000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.008700</td>
#       <td>0.006073</td>
#       <td>74.792800</td>
#       <td>18.167000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.008700</td>
#       <td>0.005909</td>
#       <td>74.772000</td>
#       <td>18.164000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.008700</td>
#       <td>0.005851</td>
#       <td>74.970300</td>
#       <td>18.163000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.008700</td>
#       <td>0.005947</td>
#       <td>74.775300</td>
#       <td>18.168000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.007500</td>
#       <td>0.005868</td>
#       <td>74.865500</td>
#       <td>18.160000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.007500</td>
#       <td>0.005995</td>
#       <td>74.852700</td>
#       <td>18.162000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.007500</td>
#       <td>0.005908</td>
#       <td>74.790600</td>
#       <td>18.156000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.007500</td>
#       <td>0.005962</td>
#       <td>74.831600</td>
#       <td>18.157000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.007500</td>
#       <td>0.005853</td>
#       <td>74.787000</td>
#       <td>18.160000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.006600</td>
#       <td>0.006084</td>
#       <td>74.638400</td>
#       <td>18.165000</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.006600</td>
#       <td>0.006116</td>
#       <td>74.727700</td>
#       <td>18.165000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.006600</td>
#       <td>0.006189</td>
#       <td>74.765800</td>
#       <td>18.158000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.006600</td>
#       <td>0.006151</td>
#       <td>74.734700</td>
#       <td>18.165000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.006600</td>
#       <td>0.006105</td>
#       <td>74.692600</td>
#       <td>18.161000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.006000</td>
#       <td>0.006103</td>
#       <td>74.686300</td>
#       <td>18.161000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2600/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2700/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2800/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2900/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-1900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3000/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-3500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=3570, training_loss=0.034986265149771, metrics={'train_runtime': 4472.184, 'train_samples_per_second': 50.87, 'train_steps_per_second': 0.798, 'total_flos': 5292075909120000.0, 'train_loss': 0.034986265149771, 'epoch': 35.0})

# %%
cuda_trainer.save_model(t5_cuda_path)
# Out:
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth/spiece.model

# %% [markdown]
# ## NL-RX Turk

# %%
from transformers import LineByLineTextDataset
from transformers import T5Tokenizer, T5ForConditionalGeneration
from datasets import load_dataset, load_metric, dataset_dict
import torch
import numpy as np

tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")
dataset = load_dataset("csv", data_files="/content/drive/MyDrive/ANLP21/data/labeled_regex_data/labeled_nlrx_turk.csv", split="train")
_dataset_dict = dataset.train_test_split(test_size=0.25)
train_val = _dataset_dict["train"].train_test_split(test_size=10/75)
train = train_val["train"]
val = train_val['test']
test = _dataset_dict["test"]
d = dataset_dict.DatasetDict({'train':train, 'val': val, 'test':test})
metric = load_metric("sacrebleu")
# Out:
# loading file https://huggingface.co/t5-small/resolve/main/spiece.model from cache at /root/.cache/huggingface/transformers/65fc04e21f45f61430aea0c4fedffac16a4d20d78b8e6601d8d996ebefefecd2.3b69006860e7b5d0a63ffdddc01ddcd6b7c318a6f4fd793596552c741734c62d
# loading file https://huggingface.co/t5-small/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/tokenizer_config.json from cache at None
# loading file https://huggingface.co/t5-small/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/06779097c78e12f47ef67ecb728810c2ae757ee0a9efe9390c6419783d99382d.8627f1bd5d270a9fd2e5a51c8bec3223896587cc3cfe13edeabb0992ab43c529
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.406701565c0afd9899544c1cb8b93185a76f00b31e5ce7f6e18bbaef02241985
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.14.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.406701565c0afd9899544c1cb8b93185a76f00b31e5ce7f6e18bbaef02241985
# Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.14.0.dev0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file https://huggingface.co/t5-small/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# Using custom data configuration default-c184eca6b8a84e7c
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-c184eca6b8a84e7c/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-c184eca6b8a84e7c/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer, model=model
)

# %%
d
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 6500
#     })
#     val: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 1000
#     })
#     test: Dataset({
#         features: ['label', 'regex'],
#         num_rows: 2500
#     })
# })

# %%
max_input_length = 512
max_target_length = 128
def preprocess_function(dataset):
    inputs = dataset["label"]
    targets = dataset["regex"]
    model_inputs = tokenizer(inputs, max_length=max_input_length, padding=True, truncation=True)
    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, padding=True, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

datasets = d.map(preprocess_function, batched=True)

for dataset in datasets:
  datasets[dataset] = datasets[dataset].remove_columns(["label", "regex"])
# Out:
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
t5_path = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex/nlrx_turk"
t5_cuda_path = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk"
# !mkdir -p $t5_path
# !mkdir -p $t5_cuda_path

# %%
d.save_to_disk(t5_cuda_path)
# Out:
# Flattening the indices:   0%|          | 0/7 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels
    
def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
# from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

# batch_size = 64

# training_args = Seq2SeqTrainingArguments(
#     t5_path,
#     evaluation_strategy = "epoch",
#     learning_rate=3e-4,
#     per_device_train_batch_size=batch_size,
#     per_device_eval_batch_size=batch_size,
#     save_steps=100,
#     save_total_limit=10,
#     num_train_epochs=35,
#     predict_with_generate=True    
# )

# trainer = Seq2SeqTrainer(
#     model,
#     training_args,
#     train_dataset=datasets["train"],
#     eval_dataset=datasets["val"],
#     data_collator=data_collator,
#     tokenizer=tokenizer,
#     compute_metrics=compute_metrics
# )

# %%
# trainer.save_model(t5_path)

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

batch_size = 64

cuda_training_args = Seq2SeqTrainingArguments(
    t5_cuda_path,
    evaluation_strategy = "epoch",
    learning_rate=3e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    save_steps=100,
    save_total_limit=10,
    num_train_epochs=35,
    predict_with_generate=True    
)

cuda_trainer = Seq2SeqTrainer(
    model,
    cuda_training_args,
    train_dataset=datasets["train"],
    eval_dataset=datasets["val"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
cuda_trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 6500
#   Num Epochs = 35
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3570
#     <div>
#
#       <progress value='3570' max='3570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3570/3570 1:16:58, Epoch 35/35]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.172671</td>
#       <td>57.133400</td>
#       <td>17.447000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.110817</td>
#       <td>60.425200</td>
#       <td>17.803000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.091354</td>
#       <td>62.089600</td>
#       <td>17.868000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.081889</td>
#       <td>63.151200</td>
#       <td>17.857000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.296300</td>
#       <td>0.074104</td>
#       <td>63.475900</td>
#       <td>17.943000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.296300</td>
#       <td>0.069612</td>
#       <td>64.433300</td>
#       <td>17.978000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.296300</td>
#       <td>0.067262</td>
#       <td>64.429500</td>
#       <td>18.014000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.296300</td>
#       <td>0.066478</td>
#       <td>63.613700</td>
#       <td>17.879000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.296300</td>
#       <td>0.062792</td>
#       <td>64.151000</td>
#       <td>17.925000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.087700</td>
#       <td>0.063234</td>
#       <td>64.446600</td>
#       <td>17.920000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.087700</td>
#       <td>0.062464</td>
#       <td>64.091900</td>
#       <td>17.866000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.087700</td>
#       <td>0.059503</td>
#       <td>64.788200</td>
#       <td>17.958000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.087700</td>
#       <td>0.059670</td>
#       <td>64.250900</td>
#       <td>17.942000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.087700</td>
#       <td>0.058574</td>
#       <td>64.717900</td>
#       <td>17.991000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.068900</td>
#       <td>0.059865</td>
#       <td>64.625100</td>
#       <td>17.959000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.068900</td>
#       <td>0.059848</td>
#       <td>64.559100</td>
#       <td>17.994000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.068900</td>
#       <td>0.058347</td>
#       <td>64.626400</td>
#       <td>17.998000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.068900</td>
#       <td>0.059346</td>
#       <td>64.216900</td>
#       <td>17.926000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.068900</td>
#       <td>0.058443</td>
#       <td>64.866000</td>
#       <td>17.982000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.059000</td>
#       <td>0.057295</td>
#       <td>64.830000</td>
#       <td>17.974000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.059000</td>
#       <td>0.058104</td>
#       <td>64.893700</td>
#       <td>18.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.059000</td>
#       <td>0.057934</td>
#       <td>64.738000</td>
#       <td>17.975000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.059000</td>
#       <td>0.056980</td>
#       <td>64.866200</td>
#       <td>18.048000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.059000</td>
#       <td>0.058473</td>
#       <td>64.457400</td>
#       <td>18.019000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.052500</td>
#       <td>0.057616</td>
#       <td>64.366500</td>
#       <td>17.959000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.052500</td>
#       <td>0.058117</td>
#       <td>64.959400</td>
#       <td>17.973000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.052500</td>
#       <td>0.057796</td>
#       <td>65.021000</td>
#       <td>18.019000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.052500</td>
#       <td>0.058341</td>
#       <td>64.854200</td>
#       <td>17.993000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.052500</td>
#       <td>0.058635</td>
#       <td>64.993900</td>
#       <td>17.986000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.047800</td>
#       <td>0.058945</td>
#       <td>65.000700</td>
#       <td>17.987000</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.047800</td>
#       <td>0.058753</td>
#       <td>64.881400</td>
#       <td>17.988000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.047800</td>
#       <td>0.058845</td>
#       <td>65.101500</td>
#       <td>18.004000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.047800</td>
#       <td>0.059024</td>
#       <td>64.795800</td>
#       <td>17.986000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.047800</td>
#       <td>0.058689</td>
#       <td>64.920800</td>
#       <td>17.995000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.044900</td>
#       <td>0.058849</td>
#       <td>65.034800</td>
#       <td>18.004000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2600/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2700/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2800/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2900/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-1900] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3000/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3100/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3200/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3300/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3400/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-3500/spiece.model
# Deleting older checkpoint [/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 64
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=3570, training_loss=0.09285836627169483, metrics={'train_runtime': 4619.6974, 'train_samples_per_second': 49.246, 'train_steps_per_second': 0.773, 'total_flos': 5412350361600000.0, 'train_loss': 0.09285836627169483, 'epoch': 35.0})

# %%
cuda_trainer.save_model(t5_cuda_path)
# Out:
# Saving model checkpoint to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk
# Configuration saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/config.json
# Model weights saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/special_tokens_map.json
# Copy vocab file to /content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk/spiece.model

# %% [markdown]
# # Inference

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch
import numpy as np
t5_cuda_path_nlrx_turk = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_turk"
t5_cuda_path_nlrx_synth = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/nlrx_synth"
t5_cuda_path_kb13 = "/content/drive/MyDrive/ANLP21/t5_eng_to_regex_cuda/kb13"
import sys
sys.path.append('/content/drive/MyDrive/ANLP21')

# %% [markdown]
# ### KB13

# %%
tokenizer = T5Tokenizer.from_pretrained(t5_cuda_path_kb13)
model = T5ForConditionalGeneration.from_pretrained(t5_cuda_path_kb13)

# %%
# model.to('cpu')
# input_ids = tokenizer("translate English to Regex: lines using 'an' before 'imal'", return_tensors='pt').input_ids
# outputs = model.generate(input_ids)
# print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
# len(d['test'][4]['regex'])

# %%
from datasets import load_from_disk
d = load_from_disk(t5_cuda_path_kb13)
d['test']
# Out:
# Dataset({
#     features: ['label', 'regex'],
#     num_rows: 206
# })

# %%
tokenizer.decode(d['test'][0]['input_ids'], skip_special_tokens=True)
# Out:
# "translate English to Regex: lines that do not contain the string 'dog' followed by a number, three times or more"

# %%
from datasets import load_dataset
full_dataset = load_dataset("csv", data_files="/content/drive/MyDrive/ANLP21/data/labeled_regex_data/labeled_nlrx_turk.csv", split="train")
full_dataset
# Out:
# Using custom data configuration default-c184eca6b8a84e7c
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-c184eca6b8a84e7c/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-c184eca6b8a84e7c/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.
# Dataset({
#     features: ['label', 'regex'],
#     num_rows: 10000
# })

# %%
tokenizer(full_dataset[i]['label'], return_tensors='pt').input_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-702e2779a910> in <module>()
# ----> 1 tokenizer(full_dataset[i]['label'], return_tensors='pt').input_ids
#
# NameError: name 'i' is not defined

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)

# %%
from regexDFAEquals import main
import tqdm
arr = []

dfa_num_correct = 0
for i in tqdm.trange(len(d['test'])):
# for i in range(len(dataset_dict['test'])):
  # print(dataset_dict['test'][i]['label'])
  input_ids = tokenizer(d['test'][i]['label'], return_tensors='pt').input_ids
  outputs = model.generate(input_ids)
  # print(dataset_dict['test'][i]['regex'])
  # print(tokenizer.decode(outputs[0], skip_special_tokens=True))
  correct = main(tokenizer.decode(outputs[0], skip_special_tokens=True), d['test'][i]['regex'])
  dfa_num_correct += correct
  arr.append((correct, len(d['test'][i]['regex']) < 15))
  # print(dfa_num_correct)

dfa_acc = dfa_num_correct / len(d['test'])
print(dfa_acc)
print(arr)
# Out:
# 100%|██████████| 206/206 [01:22<00:00,  2.51it/s]
# 0.13106796116504854
# [(0, True), (0, False), (0, True), (0, False), (0, False), (0, True), (0, True), (0, True), (0, False), (0, True), (0, False), (0, True), (0, False), (0, True), (0, False), (0, False), (1, True), (0, False), (0, False), (0, False), (0, False), (0, False), (1, True), (1, True), (0, True), (0, True), (0, True), (0, False), (1, False), (0, False), (0, False), (0, True), (0, False), (1, True), (0, False), (0, False), (0, False), (0, False), (0, True), (0, True), (0, False), (0, True), (0, False), (0, False), (0, True), (0, True), (0, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, True), (0, False), (0, True), (1, True), (0, False), (0, False), (0, True), (1, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, True), (0, False), (0, False), (0, True), (0, False), (1, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, True), (0, False), (0, False), (0, True), (0, False), (0, False), (0, False), (0, True), (0, False), (0, False), (0, False), (0, False), (0, True), (1, True), (0, True), (0, False), (0, False), (0, True), (0, False), (0, False), (1, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, True), (0, False), (0, True), (0, False), (0, False), (0, False), (0, False), (0, True), (0, True), (0, False), (0, False), (0, False), (1, True), (0, True), (0, False), (0, False), (0, True), (0, False), (1, True), (0, False), (0, False), (1, True), (0, True), (1, False), (1, True), (0, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (1, True), (0, False), (0, False), (0, False), (1, True), (0, False), (0, False), (1, True), (0, False), (0, True), (0, False), (0, False), (1, True), (0, True), (0, False), (1, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, True), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (0, False), (1, True), (0, True), (0, True), (0, True), (1, False), (0, False), (0, False), (0, True), (0, True), (0, True), (0, True), (0, True), (0, True), (0, False), (0, False), (0, True), (1, True), (0, False), (1, True), (0, False), (0, False), (1, True), (0, False), (0, False), (0, True), (1, True), (0, False), (0, True), (0, False), (1, True), (0, True), (0, False)]

# %%
len([i for i in arr if i[0] == 1])
# Out:
# 27

# %%
len([j for j in [i for i in arr if i[1]] if j[0]==1]) / len([i for i in arr if i[1]]) # accuracy on only regexes < 15 in length
# Out:
# 0.2987012987012987

# %%
from regexDFAEquals import main
import tqdm
arr = []

dfa_num_correct = 0
for i in tqdm.trange(len(d['test'])):
# for i in range(len(dataset_dict['test'])):
  # print(dataset_dict['test'][i]['label'])
  input_ids = d['test'][i]['input_ids']
  outputs = model.generate(torch.tensor([input_ids]))
  for j in range(len(full_dataset)):
    if full_dataset[j]['label'] == tokenizer.decode(input_ids, skip_special_tokens=True):
        break
  regex = full_dataset[j]['regex']
  # print(dataset_dict['test'][i]['regex'])
  # print(tokenizer.decode(outputs[0], skip_special_tokens=True))
  decoded_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
  correct = main(decoded_output, regex)
  print(decoded_output, regex, correct)
  dfa_num_correct += correct
  arr.append((correct, len(regex) < 15))
  # print(dfa_num_correct)

dfa_acc = dfa_num_correct / len(d['test'])
print(dfa_acc)
# Out:
#   0%|          | 1/2500 [03:03<127:28:42, 183.64s/it]
# ((dog.*[0-9].*)3,) ~((dog.*[0-9].*){3,}) 0
#   0%|          | 2/2500 [03:13<56:36:04, 81.57s/it]
# (([A-Za-z])|([a-z]) (~([a-z]))&(([0-9])*) 0
#   0%|          | 3/2500 [03:27<35:14:21, 50.81s/it]
# (([0-9])|(.)).*([AEIOUa (([0-9])|(.)).*([AEIOUaeiou]).* 0
#   0%|          | 3/2500 [05:56<82:22:58, 118.77s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6eeae1c00534> in <module>()
#      10   outputs = model.generate(torch.tensor([input_ids]))
#      11   for j in range(len(full_dataset)):
# ---> 12     if full_dataset[j]['label'] == tokenizer.decode(input_ids, skip_special_tokens=True):
#      13         break
#      14   regex = full_dataset[j]['regex']
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, **kwargs)
#    3231             skip_special_tokens=skip_special_tokens,
#    3232             clean_up_tokenization_spaces=clean_up_tokenization_spaces,
# -> 3233             **kwargs,
#    3234         )
#    3235
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py in _decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, spaces_between_special_tokens, **kwargs)
#     920         current_sub_text = []
#     921         for token in filtered_tokens:
# --> 922             if skip_special_tokens and token in self.all_special_ids:
#     923                 continue
#     924             if token in self.added_tokens_encoder:
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in all_special_ids(self)
#    1256         """
#    1257         all_toks = self.all_special_tokens
# -> 1258         all_ids = self.convert_tokens_to_ids(all_toks)
#    1259         return all_ids
#    1260
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py in convert_tokens_to_ids(self, tokens)
#     562         ids = []
#     563         for token in tokens:
# --> 564             ids.append(self._convert_token_to_id_with_added_voc(token))
#     565         return ids
#     566
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils.py in _convert_token_to_id_with_added_voc(self, token)
#     569             return None
#     570
# --> 571         if token in self.added_tokens_encoder:
#     572             return self.added_tokens_encoder[token]
#     573         return self._convert_token_to_id(token)
#
# KeyboardInterrupt:

# %%
dfa_acc
# Out:
# 0.059629135862319715

# %%
count = 0
for i in range(len(d['test'])):
    if len(d['test'][i]['regex']) < 15:
        count += 1
count
# Out:
# 138

# %%
len(d['test'])
# Out:
# 2500

# %%
# Out:
# 0.36893203883495146

# %%
138/2500
# Out:
# 0.0552
